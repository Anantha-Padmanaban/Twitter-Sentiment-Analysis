# %% [markdown]
# ## Importing Packages

# %%
import tweepy

import re

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib as plt
import nltk

import warnings

from textblob import TextBlob
from matplotlib import pyplot as plt

from wordcloud import WordCloud
from wordcloud import STOPWORDS

from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.stem.porter import PorterStemmer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

nltk.download('stopwords')
# %matplotlib inline
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VSmart\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Authenticate, Setting Token Acess and Instantiate API

# %%
consumer_key = "Enter Your consumerKey"
consumer_secret = "Enter Your consumerSecret"
access_token = "Enter Your AccessToken"
access_token_secret = "Enter Your AccessTokenSecret"

# %%
authenticate = tweepy.OAuthHandler(consumer_key, consumer_secret)
authenticate.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=False)

# %% [markdown]
# ## Analyzing and categorizing content from Tweets and storing in a Dictionary .

# %%
hashtag = "#championsleague"
query = tweepy.Cursor(api.search_tweets, q=hashtag).items(1000)
tweets = [{'Tweet':tweet.text,"ID":tweet.id,"Length":len(tweet.text),"Source":tweet.source,"Favourites":tweet.favorite_count,"Reweet_count":tweet.retweet_count, 'Timestamp':tweet.created_at} for tweet in query]

# %% [markdown]
# ## Converting Dictionary into DataFrame

# %%
tweets = pd.DataFrame.from_dict(tweets)
tweets.head()
# Out:
#                                                Tweet                   ID  \
# 0  ICC and all other cricket boards plz Bring bac...  1538453008517697536
# 1  খুন করতে চেয়েছিলেন মেসি! \n\n#LionelMessi #Me...  1538451511620947968
# 2  RT @julianoback2: Golaço de bicicleta no #FIFA...  1538451413830967296
# 3  Golaço de bicicleta no #FIFA22 \n😎😎💙🖤⚽💪💪🔥.\n#P...  1538450193783431169
# 4  RT @TheMattDP10: 💣CLAMOROSO DI MARZIO | "FOLLI...  1538449057563164674
#
#    Length               Source  Favourites  Reweet_count  \
# 0     133  Twitter for Android           0             0
# 1     121      Twitter Web App           0             0
# 2     130           PSGBotLive           0             1
# 3     112  Twitter for Android           0             1
# 4     140      Zona Bianconeri           0             1
#
#                   Timestamp
# 0 2022-06-19 09:25:54+00:00
# 1 2022-06-19 09:19:58+00:00
# 2 2022-06-19 09:19:34+00:00
# 3 2022-06-19 09:14:43+00:00
# 4 2022-06-19 09:10:12+00:00

# %% [markdown]
# ## Analysing the Data

# %%
tweets.head(10)
# Out:
#                                                Tweet                   ID  \
# 0  ICC and all other cricket boards plz Bring bac...  1538453008517697536
# 1  খুন করতে চেয়েছিলেন মেসি! \n\n#LionelMessi #Me...  1538451511620947968
# 2  RT @julianoback2: Golaço de bicicleta no #FIFA...  1538451413830967296
# 3  Golaço de bicicleta no #FIFA22 \n😎😎💙🖤⚽💪💪🔥.\n#P...  1538450193783431169
# 4  RT @TheMattDP10: 💣CLAMOROSO DI MARZIO | "FOLLI...  1538449057563164674
# 5  Me acaban de pitar penalti por una entrada aqu...  1538448476861878272
# 6  💣CLAMOROSO DI MARZIO | "FOLLIA DELLA JUVENTUS ...  1538447925713551360
# 7  Ousmane Dembele is 'READY to join Chelsea but ...  1538447340893356032
# 8  @SmallStreamersC @SmallStreamersR Will we fini...  1538444373247016967
# 9  RT @Chris_e_smithy: 2 autos from one box of #C...  1538442947099762689
#
#    Length               Source  Favourites  Reweet_count  \
# 0     133  Twitter for Android           0             0
# 1     121      Twitter Web App           0             0
# 2     130           PSGBotLive           0             1
# 3     112  Twitter for Android           0             1
# 4     140      Zona Bianconeri           0             1
# 5     135   Twitter for iPhone           0             0
# 6     138   Twitter for iPhone           2             1
# 7     136     Article Tweetbot           0             0
# 8     140  Twitter for Android           0             0
# 9     140        SportsCardBot           0             1
#
#                   Timestamp
# 0 2022-06-19 09:25:54+00:00
# 1 2022-06-19 09:19:58+00:00
# 2 2022-06-19 09:19:34+00:00
# 3 2022-06-19 09:14:43+00:00
# 4 2022-06-19 09:10:12+00:00
# 5 2022-06-19 09:07:54+00:00
# 6 2022-06-19 09:05:43+00:00
# 7 2022-06-19 09:03:23+00:00
# 8 2022-06-19 08:51:36+00:00
# 9 2022-06-19 08:45:56+00:00

# %%
tweets.shape
# Out:
# (1000, 7)

# %%
tweets.dtypes
# Out:
# Tweet                        object
# ID                            int64
# Length                        int64
# Source                       object
# Favourites                    int64
# Reweet_count                  int64
# Timestamp       datetime64[ns, UTC]
# dtype: object

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tweet         1000 non-null   object
#  1   ID            1000 non-null   int64
#  2   Length        1000 non-null   int64
#  3   Source        1000 non-null   object
#  4   Favourites    1000 non-null   int64
#  5   Reweet_count  1000 non-null   int64
#  6   Timestamp     1000 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(4), object(2)
# memory usage: 54.8+ KB

# %%
tweets.describe(include = 'all')
# Out:
#                                                     Tweet            ID  \
# count                                                1000  1.000000e+03
# unique                                                693           NaN
# top     RT @Madridcamiseta7: Chicos y chicas ayudemos ...           NaN
# freq                                                   53           NaN
# first                                                 NaN           NaN
# last                                                  NaN           NaN
# mean                                                  NaN  1.537820e+18
# std                                                   NaN  3.004259e+14
# min                                                   NaN  1.537355e+18
# 25%                                                   NaN  1.537549e+18
# 50%                                                   NaN  1.537796e+18
# 75%                                                   NaN  1.538092e+18
# max                                                   NaN  1.538453e+18
#
#              Length               Source   Favourites  Reweet_count  \
# count   1000.000000                 1000  1000.000000   1000.000000
# unique          NaN                   58          NaN           NaN
# top             NaN  Twitter for Android          NaN           NaN
# freq            NaN                  417          NaN           NaN
# first           NaN                  NaN          NaN           NaN
# last            NaN                  NaN          NaN           NaN
# mean     133.308000                  NaN     2.201000    115.685000
# std       15.651521                  NaN    13.382589   1336.523019
# min       38.000000                  NaN     0.000000      0.000000
# 25%      135.000000                  NaN     0.000000      0.000000
# 50%      140.000000                  NaN     0.000000      1.000000
# 75%      140.000000                  NaN     0.000000     10.000000
# max      144.000000                  NaN   239.000000  28758.000000
#
#                         Timestamp
# count                        1000
# unique                        998
# top     2022-06-18 11:12:10+00:00
# freq                            2
# first   2022-06-16 08:41:35+00:00
# last    2022-06-19 09:25:54+00:00
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN

# %%
''' checking null values '''
tweets.isnull().sum()
# Out:
# Tweet           0
# ID              0
# Length          0
# Source          0
# Favourites      0
# Reweet_count    0
# Timestamp       0
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
# Time Series
time_likes = pd.Series(data=tweets['Length'].values, index=tweets['Timestamp'])
time_likes.plot(figsize=(16, 4))
plt.show()

# %%
time_favs = pd.Series(data=tweets['Favourites'].values, index=tweets['Timestamp'])
time_favs.plot(figsize=(16, 4))
plt.show()

# %%
time_retweets = pd.Series(data=tweets['Reweet_count'].values, index=tweets['Timestamp'])
time_retweets.plot(figsize=(16, 4), color='r')
plt.show()

# %%
# Layered Time Series:
time_likes = pd.Series(data=tweets['Favourites'].values, index=tweets['Timestamp'])
time_likes.plot(figsize=(16, 4), label="Favourites", legend=True)
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
time_retweets = pd.Series(data=tweets['Reweet_count'].values, index=tweets['Timestamp'])
time_retweets.plot(figsize=(16, 4), label="Reweet_count", legend=True)
plt.show()

# %% [markdown]
# ## Perform Sentiment Analysis on selected Tweets and adding into the respective Sets

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
#Perform sentiment analysis on selected tweets and adding into the respective sets
def analyze_sentiment(tweet):
    analysis = TextBlob(clean_tweet(tweet))
        
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
def analyze_senti(sentiment):
    if sentiment > 0:
        return "Positive"
    elif sentiment ==0:
        return "Neutral"
    else:
        return "Negative"

# %%
def analye_sentiment(tweet):
    analysis = TextBlob(clean_tweet(tweet))
    return analysis.sentiment.polarity

# %%
df['sentiment'] = np.array([analyze_sentiment(tweet) for tweet in tweets['Tweet']])
df['popularity']= np.array([analyze_senti(sentimen) for sentimen in tweets['sentiment']])
df['sentimentValue'] = np.array([analye_sentiment(tweet) for tweet in tweets['Tweet']])

# %% [markdown]
# ## Exporting Datasets from DataFrame to CSV file

# %%
tweets.to_csv('ChampionsLeague.csv')

# %%
tweets = pd.read_csv('ChampionsLeague1.csv')
tweets = tweets[['Tweet','popularity']]

# %%
''' checking null values '''
tweets.isnull().sum()
# Out:
# Tweet         0
# popularity    0
# dtype: int64

# %% [markdown]
# ## Splitting dataset into train and test dataset

# %%
train, test = train_test_split(tweets,test_size = 0.1)
# Removing neutral sentiments from datasets
data_prep = train[train.popularity != "Neutral"]

# %% [markdown]
# ## Separating the positive and negative data from dataset

# %%
train_positive = data_prep[ data_prep['popularity'] == 'Positive']
train_positive = train_positive['Tweet']
train_negative = data_prep[ data_prep['popularity'] == 'Negative']
train_negative = train_negative['Tweet']

# %%
#Defining a function to plot the datas in wordcloud
def wc_draw(datas, color = 'black'):
    words = ' '.join(datas)
    cleaned_word = " ".join([word for word in words.split() if 'http' not in word and not word.startswith('@') and not word.startswith('#') and word != 'RT'])
    words = WordCloud(stopwords=STOPWORDS,background_color=color,width=2500,height=2000).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(words)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Priting the Positive words using WordCloud

# %%
print(" ==== Positive words ====")
wc_draw(train_positive,'white')
# Out:
#  ==== Positive words ====

# %% [markdown]
# ## Priting the Negative words using WordCloud

# %%
#plotting the negative words using wordcloud
print("====  Negative words  ====")
wc_draw(train_negative)
# Out:
# ====  Negative words  ====

# %% [markdown]
# ##  Preproecessing

# %%
c = []

for i in range(0, 1000):
    ''' removing characters except a-z and A-Z'''
    r = re.sub('[^a-zA-Z]', ' ', data['Tweet'][i])
    ''' converting every word into lower word'''
    r = r.lower()
    ''' splitting text '''
    r = r.split()
    ''' apllying Stemming '''
    ps = PorterStemmer()
    ''' removing stopwords '''
    sw = stopwords.words('english')
    sw.remove('not')
    r = [ps.stem(word) for word in r if not word in set(sw)]
    r = ' '.join(r)
    c.append(r)

# %%
c
# Out:
# ['end handbal herren championsleagu finalfour final telekomveszprem vs vivekielc thwkiel vs fcbarcelona',
#  'bolsonarista kassio nune usou jatinho de um advogado q tem processo em curso stf tour custou mil e http co oulqik rk',
#  'rt infamouscaveman finish within top build finish championsleagu europaleagu spot everyth',
#  'rt infamouscaveman blakjokk blazedrt spideyrt promoteamgam rtsmallstream supstream promo stream wwwanpau sme rt wil',
#  'blakjokk blazedrt spideyrt promoteamgam rtsmallstream supstream promo stream wwwanpau sme rt http co sjh pgz',
#  'rt infamouscaveman vanessa step blazedrt spideyrt promoteamgam rtsmallstream supstream promo stream wwwanpau sme rt w',
#  'vanessa step blazedrt spideyrt promoteamgam rtsmallstream supstream promo stream wwwanpau http co grouffyg',
#  'mandi hale blazedrt sme rt promoteamgam rtsmallstream supstream promo stream streamersrt http co v lpldbgi',
#  'skthekingyt finish within top build finish championsleagu europaleagu spo http co foszqr pmv',
#  'help develop kid footbal skill pro coach footbal skill assess download http co ih vuqowfp',
#  'championsleagu fake ticket disast could avoid use blockchaintechnolog http co ef wzl tn',
#  'http co pa ygpbstw championsleagu footbal',
#  'partido de hoy torneo brasileirao inscribit particip en el prode de la championsleagu el http co mni u',
#  'oi galera conhecem ditado que pagam os justo pelo pecador dom quijot vamosjuntospelobrasil http co uuwfotmbmi',
#  'spagetti review fathersday kinnporscheworldtour insid alway bbq coffeecr http co hbnvt vguv',
#  'rt thedar ms final got pic champion leagu trophi got fun juneteenth game http co n dtv bw',
#  'rt vicki ok final en el etihad semi ida championsleagu el manciti se impuso desd su idea de juego el realmadrid aprovech',
#  'rt panafricafooti malian midfield yve bissouma excit play champion leagu blockbust move bri',
#  'ingresa mi canal de youtub te pierda el ep lisi de la final de la championsleagu el de http co iucieeic',
#  'son first champion leagu final year ago romafin uclfin championsleagu roma italia http co bxalmdh uj',
#  'rt davidkbry english soccer brexit brexit championsleagu',
#  'dominant liverpool demuestra al villarr que hay nivel en la champion leagu http co ecjzblqtl championsleagu',
#  'la championsleagu espera por juli n lvarez detal http co qcau g ld',
#  'le gusta el f tbol ambient de champion leagu championsleagu vamo rodolfo rhganador http co vpiuwmxtxt',
#  'rt realmadridcffr rodrygo le gardien de de r serv sur le banc dit il benzema va le fair j ai pen non est ce qu',
#  'wallpap k real madrid championsleagu http co f tftjmwij',
#  'omartoctoc edenmadriz encima ganaron su copa de championsleagu',
#  'manutd theyv not made like trebl prem facup championsleagu http co nw hhhgi',
#  'becom member team let earn togeth guy match directli team let play tomorrow gam http co hxdjbf wox',
#  'e investigan una persona por vender entrada falsa de la final de championsleagu http co j dqu jbao',
#  'rt ivancar ahora se vien la la championsleagu la conferenceleagu la copalibertador http co lf yymc',
#  'cristiano te vaya quedar sin jugar tu competici n favorita osea championsleagu seria una lastima http co uwvd mfrlc',
#  'sure match flora tallinn nomm jk kalju bet floratallinn estonia championsleagu http co kcl kem iu',
#  'ahora se vien la la championsleagu la conferenceleagu la copalibertador http co lf yymc',
#  'final got pic champion leagu trophi got fun juneteenth game http co cscqabug b',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'uefa plan ruin championsleagu http co kan oj q via youtub',
#  'finish within top build finish championsleagu europaleagu spot everythin http co loy nsbdq',
#  'smallstreamersc smallstreamersr finish within top build finish championsleagu http co psid fe',
#  'social pro mote finish within top build finish championsleagu europaleagu http co xrfq oem',
#  'malian midfield yve bissouma excit play champion leagu blockbust move http co e ocoahyxl',
#  'food alway good idea wijnaldum ansufati lingard socceraid rogermoor unitedkingdom asensio sport http co f mpq',
#  'rt callmeador see eye urgent k infect ekeh ador comedi rmach beastfdf strangerth',
#  'http co yuf vjnwtc footbal soccer messi ronaldo championsleagu barcelona realmadrid neymar cr http co hq sgighq',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'cobramo picketazo en la ml momio pronosticosdeportivo championsleagu calientemx futbol http co gviefw yoq',
#  'beinsport bein bein ssc sport championsleagu http co xq ao oy',
#  'sabiasqu cr lleva temporada al pie del ca n como ximo g leador en lo clube dond ha estado vest http co noognf uz',
#  'rt matmosciatti lukaku inter stato bene ha vinto e vuol continuar vincer haaland al manciti lotter per vincer la',
#  'finish within top build finish championsleagu europaleagu spot everythi http co kxyjnrfhn',
#  'rt asar b caleb not curs dark light candl guid us dark safe sane f',
#  'dokter timna mesir ungkap fakta moham salah ketika bertand di final liga champion apa itu http co fenq qc l',
#  'rt matmosciatti matic se mourinho lo ha scelto sar util alla squadra un grand giocator penso abbia la mentalit giusta per',
#  'surpris win ladecimoquinto next season underestim real madrid peril http co qwdj fpst',
#  'http co yuf vjnwtc footbal soccer messi championsleagu ronaldo cristianoronaldo barcelona http co vuzmyrmtf',
#  'au der traum vom handbal rchen der thw kiel ist im halbfinal um die championsleagu durch ein nied http co jqxzauugx',
#  'libr de lesion jug minuto premierleagu partido gole asistencia cleansheet http co h iuwlpot',
#  'rt artistofthezeu savag pad lock http co rovmcmfk r via youtub championsleagu elonmusk cryptocurr daysthisday',
#  'rt milancrit buon compleanno al mister dei mister fabio capello unico allenator del milan vincer un campionato senza sconfi',
#  'rt romo arena torneo txapelketa otra experiencia ant un equipo championsleagu el arena se ha enfrentado en el torn',
#  'torneo txapelketa otra experiencia ant un equipo championsleagu el arena se ha enfrentado en e http co sbukn n',
#  'os gico p esquerdo championsleagu dimaria ozil robben cheguevara samantha http co fkufav iul',
#  'rt act pal rememb celtic fine uefa fli palestin flag championsleagu play match hapo',
#  'rt botonrojom festiv del sotol en torr n est casi listo sotol fest trc gueno para noticia encuentra art culo de',
#  'che intenditor di calcio roma totti serieatipo totti championsleagu http co clwpm xtr',
#  'por aqu os dejo una foto de mi nuevo tatuaj halamadrid championsleagu realmadrid http co pxba nnkto',
#  'il n pa thibaut courtoi il n pa de championsleagu http co hudpqnys',
#  'come watch team play seattl championsleagu ecnlplayoff ecnl http co oeysremacr',
#  'approch de la fin de notr rie le bilan place aux entra neur de la saison dan le grand championnat eur http co fuubgtdkdu',
#  'der thwkiel konnt im halbfinal der championsleagu k ln nur ein h lfte lang mit dem fc barcelona mithalten http co tv ag yjhi',
#  'day wheel seattl get extra touch ecnlplayoff championsleagu http co vbtm ih',
#  'rt paulinamkama congrat stephencurri final mvp nba champion welcom celebr championship tan',
#  'rt patrick hd querido equipo que la voce de la afici n os gu en hacia la victoria vamo todo junto porqu somo uno somo el',
#  'rt zekko new video what next chelsea http co elnhktbfcv rt appreci z chelsea premierleagu lukaku tuch',
#  'gentlemen footbal brand soccer footbal style worldcup menwithclass classygentlemen eleg http co gwoqlnlmoy',
#  'theelmsschool pupil jack great job ellen gilt young handler championship class http co r gpxrrxha',
#  'rt nemesispopmus camila cabello arrasa trasladando su ritmo la final de la championsleagu http co fc ufh ix http co',
#  'alti st futbol http co bneokomlb youtub arac l yla alti st futbol per emb http co nbbnxiee b',
#  'om vivekielc handbal team beat hungarian telekomveszpr semifin ehf http co fmnd cmcrv',
#  'che ne pensat inter lautaro lautaromartinez calciomercato argentina seriea championsleagu http co h prmfhjw',
#  'rt skysportd handbal rekordmeist thw kiel hat den einzug in champion leagu endspiel verpasst die schleswig holstein verloren ih',
#  'lor de la nde demi final ehfcl championsleagu fcbhandbol l emport contr thw handbal g http co sav rbnnij',
#  'rt vip deportivo actualidad comienza la champion vipdeportivo por juansempere ucl championsleagu islandia http',
#  'championsleagu',
#  'rt skysportd handbal rekordmeist thw kiel hat den einzug in champion leagu endspiel verpasst die schleswig holstein verloren ih',
#  'handbal rekordmeist thw kiel hat den einzug in champion leagu endspiel verpasst die schleswig holstein ver http co ggkxu tkci',
#  'back back defeat st mari fight back beat undef super sun cl srilankafootbal http co qlf g',
#  'nutmeg footbal benjamin youth championsleagu profession thebest fcbarcelona fcbayern realmadrid http co ytt dj',
#  'rt celticview championsleagu return paradis day june look tho',
#  'facial express show fcbarcelona championsleagu laligasantand http co z jjoeurnm',
#  'rt matmosciatti matic se mourinho lo ha scelto sar util alla squadra un grand giocator penso abbia la mentalit giusta per',
#  'european golden shoe stand http co etd euja robert lewandowski goal kylian mb http co ogvdn k k',
#  'rt footballhouseuk rodrygo uefa champion leagu final luka modri pass front moham salah said next',
#  'rodrygo uefa champion leagu final luka modri pass front moham salah said nex http co lqfg eedv',
#  'matic se mourinho lo ha scelto sar util alla squadra un grand giocator penso abbia la mentalit giusta http co miocyxuozz',
#  'lukaku inter stato bene ha vinto e vuol continuar vincer haaland al manciti lotter per vincer http co j iymjj ye',
#  'diamondleagu championsleagu meet http co erxtsd',
#  'miss grate time wish best unless get drawn aga http co r vpbccrc',
#  'rt themattdp noooo noooo la juventu si rovina co mi rifiuto di http co oegmi wqx ronaldo juventu paratici marot',
#  'rt allanbart n emp che c est rafra chissant de voir de tranger se demand pourquoi ce polici frapp san raison cet homm po',
#  'rt allanbart jamai de leur faut darmanin lallemand ucl uefa championsleaguefin championsleagu stadedefr pour financ',
#  'rt allanbart macron va finir par appr cier le fran ai darmanin stadedefr darmanin darmanindemiss macron lallement',
#  'rt allanbart il ne leur rest plu que le sort oubliett lancer sur le lecteur avant le l gisl accio la moula',
#  'noooo noooo la juventu si rovina co mi rifiuto di http co oegmi wqx ronaldo juventu paratici http co aprckkdwh',
#  'mundodeportivo championsleagu para un soberbio da ese resultado',
#  'realmadridarab realmadrid halamadrid halamadridynadama realmadrid rma http co xb nbqvmff',
#  'marcoasensio buen pero con championsleagu',
#  'beinsport bein bein ssc sport championsleagu http co anaean x u',
#  'best player world time cristiano cristianoronaldo cr ronaldo messi cristiano http co cip ip kjx',
#  'championsleagu return paradis day june look http co dbcet csxo',
#  'messi championsleagu psg footbal',
#  'new video fm liverpool episod http co omzwlvzyez come check page fm http co qsvxd rz',
#  'rt cherguiagroup sometim want get away run tree mulshi pune photooftheday photo natur beauti beau',
#  'victorlozano championsleagu realmadrid halamadrid http co tubpfsoytv',
#  'alguien ma le preocupa ver cristiano en championsleagu',
#  'fabio capello cumpl hoy os el italiano en su faceta de dt ha ganado seriea laliga sup http co zdb qzlt',
#  'passionnant demi final ehfcl championsleagu avec la victoir final de kielcehandbal c http co lmwxloizma',
#  'rt polisharena om vive kielc w final ligi mistrz w kielcehandbal telekomveszprem gratulujemi czekami na',
#  'rt polisharena om vive kielc w final ligi mistrz w kielcehandbal telekomveszprem gratulujemi czekami na',
#  'rt mxr throw back unforgett moment listen peter druri championsleagu realmadrid ucl miracl halamadridyn',
#  'kielcehandbal w final ligi mistrz w final championsleagu',
#  'rt polisharena om vive kielc w final ligi mistrz w kielcehandbal telekomveszprem gratulujemi czekami na',
#  'rt polisharena om vive kielc w final ligi mistrz w kielcehandbal telekomveszprem gratulujemi czekami na',
#  'om vive kielc w final ligi mistrz w kielcehandbal telekomveszprem gratulujemi cze http co mtfm knnmn',
#  'break sadio mane verg seal move bayern munich club prepar improv offer http co jlhyiv xoh',
#  'day year ago pakistan champion trophi alhamdulillah best day life allah pak bohat kamyab http co zwexoailu',
#  'la uefa si esprim dopo mesi con una sanzion al psg per fatti accaduti al termin della gara di http co mtb uo',
#  'rank da piccola storia da grand la rincorsa del milan al vertic europa championsleagu ucl http co dz klwf',
#  'yve bissouma es el tercer fichaj estelar del spur es tottenham tottenhamhotspur spur premierleagu http co rq vpthsey',
#  'quiz predict show associ msccasino click link best odd http co zdxjojogg',
#  'rt ahelu pue ya rebasamo al mazatlanfc empatamo al xolo en tulo tiembla clubpueblamx campeon derhum',
#  'pue ya rebasamo al mazatlanfc empatamo al xolo en tulo tiembla clubpueblamx campeon http co oqu xdlmg',
#  'soccer match updat satsport khelkhelkebanaocash soccer footbal http co gt mwt w',
#  'rt unaaaii fichajazo absoluto para cont bissouma como acompa ant de bentancur h jbjerg en la medular para competir por la plaz',
#  'sadio man deja liverpool luego de os espectacular liverpoolfc liverpool bayern bayernmunich sadioman http co rroyexyrrv',
#  'el ajax de van gaal fue uno de lo equipo que han marcado tendencia para ele f tbol moderno vangaal http co x hy gyvtf',
#  'rt superluca bought box laaaaadi sheer boredom addict make offer want anyth thehobbi soc',
#  'rt dmcredx go watch http co dzatfsldi footbal soccer nfl sport futbol fifa sport premierleagu messi calcio',
#  'rt superluca bought box laaaaadi sheer boredom addict make offer want anyth thehobbi soc',
#  'go watch http co dzatfsldi footbal soccer nfl sport futbol fifa sport premierleagu http co ya rs deek',
#  'fbiasin il manciti ha preso haaland se guardiola non vinc la championsleagu neanch quest anno proprio http co sv ydyn',
#  'vincent labrun veut que le footbal fran ai fass parti du top en europ ici vou croyez la ligu c http co x ktqnfigv',
#  'bought box laaaaadi sheer boredom addict make offer want anyth http co hubkhrryxc',
#  'enter deport modric se burl de salah luego de ganar la champion esto fue lo que dijo lucamodr http co rhrjiyuiv',
#  'aposta dep sito de r maior odd mercado saqu muito r pido link de cadastro cadastr se j http co zn ufzho',
#  'mario g tze saldr del psv cu nto cuesta cu nto gana de salario psv gotz eintracht benfica ml http co gz bb umu',
#  'word cannot describ ucl campaign one forev memori madridista around http co pxi ddvsl',
#  'povo handebol que foi abertura dess primeiro jogo da final da cl arrepi championsleagu handbal men',
#  'rt hotstuffzf plu difficil de remport la premierleagu que la championsleagu cett ann e cett th ori sera approuv e ten ha',
#  'la noch gica del real madrid hasta levantar la decimocuarta e http co htkpywvqp http co l enzux e',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt themattdp bomba di marzio ora ufficial tutto firmato per la juventu http co zhrdvvwaph ronaldo juventu paratici',
#  'bomba di marzio ora ufficial tutto firmato per la juventu http co zhrdvvwaph ronaldo juventu http co ikhagc qox',
#  'rt bigghomiebandz http co kwghdlflw explor independ follow fyp foryoupag linktre music bigghomiebandz witda gs un',
#  'rt bigghomiebandz http co vnj c rvxo bigghomiebandz applemus explor explor cloud smoke cannabi championsleagu drstra',
#  'first championsleagu tudn latincup gave away europeancup toda http co cxkkymfnhf',
#  'rt matthewwimpenni championsleaguefin championsleagu liverpoolvsrealmadrid liverpoolfc liverpoolfan love footbal footballtea',
#  'rt hotstuffzf plu difficil de remport la premierleagu que la championsleagu cett ann e cett th ori sera approuv e ten ha',
#  'bremer esc allo scoperto voglio giocar la championsleagu leagu notizieint http co zhxtqbvd',
#  'plu difficil de remport la premierleagu que la championsleagu cett ann e cett th ori sera approuv e http co xsyn fnq',
#  'rt realmadridcffr rodrygo contr manchest citi au bernabeu je sui relev benzema alor qu il tait au sol et il demand',
#  'rt realmadridcffr rodrygo la meilleur quip que vou ayez affront e en ligu de champion manchest citi vou devez continu',
#  'rt realmadridcffr le support de liverpool et du real madrid seront entendu par le nat fran ai mardi apr le incid de la',
#  'rt realmadridcffr rodrygo le gardien de de r serv sur le banc dit il benzema va le fair j ai pen non est ce qu',
#  'rt eagencyoffici enquiri agenc grate adoatv gh support recruit go volunt placement',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt typ pl w sieci pojawi si ju podzia koszyk w na losowani fazi grupowej ligi mistrz w w sezoni jak waszym zdaniem mog',
#  'w sieci pojawi si ju podzia koszyk w na losowani fazi grupowej ligi mistrz w w sezoni jak waszym z http co z wneuuw',
#  'nicoz certo se vogliamo vincer il campionato vorrai dire la c l per tutt le squadr italian oramai con c http co wvvahrwtzc',
#  'set remind nd aug mindthegap coy thfc championsleagu bottlejob http co ntlvseooux',
#  'new spursoffici kit deliv today alreadi worn happi choic player badg bec http co ocddfiehfj',
#  'rt matthewwimpenni championsleaguefin championsleagu liverpoolvsrealmadrid liverpoolfc liverpoolfan love footbal footballtea',
#  'rt matthewwimpenni championsleaguefin championsleagu liverpoolvsrealmadrid liverpoolfc liverpoolfan love footbal footballtea',
#  'dinamokiev head coach mircealucescu get championsleagu serious want show ukrainian http co shimro nux',
#  'inter e juventu l annuncio di bremer voglio giocar championsleagu l anno prossimo calciomercato http co cnk cmq',
#  'rt iexpresssport uefa clear execut committe member nasser khelaifi punish despit find club parissa',
#  'bremer voglio giocar la champion intervistato da resenhaespn bremer ha rivelato che lascer il torino http co kuxi omqu',
#  'rt salv amoroso napoli aslan baladz dg dinamobatumi adjarasporttv kvaratskhelia un giocator molto important per noi',
#  'rt realmadridcffr rodrygo le gardien de de r serv sur le banc dit il benzema va le fair j ai pen non est ce qu',
#  'rt realmadridcffr rodrygo contr manchest citi au bernabeu je sui relev benzema alor qu il tait au sol et il demand',
#  'rt realmadridcffr rodrygo la meilleur quip que vou ayez affront e en ligu de champion manchest citi vou devez continu',
#  'rt realmadridcffr le support de liverpool et du real madrid seront entendu par le nat fran ai mardi apr le incid de la',
#  'rt realmadridcffr rodrygo le gardien de de r serv sur le banc dit il benzema va le fair j ai pen non est ce qu',
#  'sevenup hai colto il senso della situazion possono dirci ci che vogliono sappiamo bene che il problema http co e vnc oia',
#  'rt mukingaemma messi herrera watch neymar see hard defend invent',
#  'rt realmadridcffr rodrygo contr manchest citi au bernabeu je sui relev benzema alor qu il tait au sol et il demand',
#  'rodrygo contr manchest citi au bernabeu je sui relev benzema alor qu il tait au sol et il dema http co zjxnoz',
#  'rodrygo la meilleur quip que vou ayez affront e en ligu de champion manchest citi vou devez continu http co wt rhqyi',
#  'le support de liverpool et du real madrid seront entendu par le nat fran ai mardi apr le incid de http co lo wdpmgr',
#  'buon compleanno al mister dei mister fabio capello unico allenator del milan vincer un campionato senza http co jewn yoybq',
#  'rodrygo le gardien de de r serv sur le banc dit il benzema va le fair j ai pen non est ce http co qbsafub',
#  'rt klipdraw start season predict good show olympiqu marseil jorg sampaoli',
#  'drop championsleagu group stage sinc new format say worst http co wqvc n n h',
#  'enquiri agenc grate adoatv gh support recruit go volunt placemen http co ifdhi j yw',
#  'actualidad comienza la champion vipdeportivo por juansempere ucl championsleagu islandia http co yogb vare',
#  'actualidad comienza la champion vipdeportivo por juansempere ucl championsleagu islandia http co lnixlsgu z',
#  'not win championsleagu bayern citi side deem failur http co ixoorplr',
#  'rt olorisport aveng salah championsleagu championsleaguefin http co autlcgarob',
#  'man fail win championsleagu best bayern side citi good win leagu http co ys msh mwu',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt sport nft card check http co zfrxrrcpmb haaland bvb footbal borussiadortmund bundesliga dortmund messi champ',
#  'check http co zfrxrrcpmb haaland bvb footbal borussiadortmund bundesliga dortmund messi http co dzwtfz bn',
#  'game player need shirt nufcfan newcastleunit championsleagu http co prdmayota',
#  'liguedeschampion l interescald andorr entr en lice footbal ucl championsleagu andorra http co hn n sdom',
#  'rt eficaciadeport marcelo en la unica final de championsleagu que jug desemp segun l su papel ma important ejemplo de',
#  'day uefa championsleagu final kick ball go auction truli uniqu opport http co zsw vs oh',
#  'rt monikal ticabolsonarista bancado por advogado ministro stf vai de jatinho pari para final da championsleagu advogad',
#  'ticabolsonarista bancado por advogado ministro stf vai de jatinho pari para final da championsleagu http co sgtw fipko',
#  'rt chrisalucard olympiaco close reach agreement year old right back sime vrsaljko olympiako olympiacosfc',
#  'lebombedivlad peccato che arsen sta prendendo gabrieljesu il tottenham ha gi kean e il manchesterunit http co b xjcgami',
#  'marcelo en la unica final de championsleagu que jug desemp segun l su papel ma important ejemplo http co ulnx fve q',
#  'verdad polemica futebol sergio busquet augu foi muito melhor volant que casemiro foi ou http co soc avg',
#  'bremer sto valutando divers propost voglio giocar championsleagu e se chiama l italia http co arp osd aq',
#  'rodrygo champion leagu final give guard honour liverpool salah come http co es qkiei',
#  'torino bremer ai saluti voglio giocar la championsleagu http co zr ltppwa',
#  'rt chrisalucard olympiaco close reach agreement year old right back sime vrsaljko olympiako olympiacosfc',
#  'rt chrisalucard olympiaco close reach agreement year old right back sime vrsaljko olympiako olympiacosfc',
#  'rt chrisalucard olympiaco close reach agreement year old right back sime vrsaljko olympiako olympiacosfc',
#  'olympiaco close reach agreement year old right back sime vrsaljko olympiako http co n crtvsmdj',
#  'rt themattdp boom un fenomeno dal brasil per la juventu http co xifn ronaldo juventu paratici marotta forzaju',
#  'boom un fenomeno dal brasil per la juventu http co xifn ronaldo juventu paratici marotta http co piaxdldgr',
#  'greatest midfield trio modric kroo casemiro realmadrid championsleagu uefachampionsleaguefin http co rpvtzee sc',
#  'burberri announc son heung min new brand ambassador burberri premierleagu ucl championsleagu http co gjbhoasfj',
#  'gameplay de fifa en el torneo championsleagu dame like http co fg cibdof',
#  'koulibali fa benissimo spalletti dimettersi se il burino romano gli vend il comandant si partecipa x vincer http co grzfnhoeh',
#  'se reencuentran en francia sampaoli sue con alexi lenglet para reforzar al marsella con mira la http co e akymk',
#  'su skysport la final di championsleagu maschil di pallamano ehffin http co ewqigwaahi',
#  'rt mr bet brazilian youngster viniciusjunior new deal real madrid run accord fabrizioromano',
#  'le voci le parol di bremer alla trasmission resenha espn tra ambizioni e mercato voglio giocar http co aixlqzipp',
#  'che ne pensat inter bremer seriea torino championsleagu ucl news giugno calciomercato http co yjkkj x x',
#  'brazilian youngster viniciusjunior new deal real madrid run accord fabrizioromano http co zsmiuakh',
#  'rt english real madrid hope unveil new bernab u end year http co twz ggwcd realmadrid laliga champ',
#  'rt raulorvanano el futbol de estufa est todo lo que da en europa mientra el brasil dani alv niega su llegada al rcd mallorc',
#  'real madrid hope unveil new bernab u end year http co twz ggwcd realmadrid http co odsf j fw',
#  'fantacalcio le statistich della championsleagu della redazion di fantapiu stat fantastat http co yjncjloq',
#  'gentlemen footbal brand soccer footbal style worldcup menwithclass classygentlemen eleg http co h q yoo b',
#  'champion leagu hamid jamshidian publish elit galleri http co jteuzddryf footbal soccer http co mmf fpcasc',
#  'world cup worldcup championsleagu premierleagu bundesliga laliga footbal soccer europaleagu http co tdarw etel',
#  'world cup worldcup championsleagu premierleagu bundesliga laliga footbal soccer europaleagu http co joywf b',
#  'rt danielebartocc fabio caressa di sky stasera ripe san ginesio fabiocaressa skysport sky nazional seriea championsleagu calc',
#  'soccer match updat satsport http co vfveiqnspl',
#  'world cup worldcup championsleagu premierleagu bundesliga laliga footbal soccer europaleagu http co dswk jy e',
#  'rt zwa pleasant memori championsleagu http co wg l zq',
#  'world cup worldcup championsleagu premierleagu bundesliga laliga footbal soccer europaleagu http co znkbeqtr',
#  'pleasant memori championsleagu http co wg l zq',
#  'british concept footbal sonheungmin sonni tottenham harrykan england premierleagu ucl http co nosz klg b',
#  'eaaa winner uefa ch mpion leagu halamadrid uefachampionsleaguefin realmadrid http co k wxi p vy',
#  'love footbal realmadrid championsleagu modric http co gphflajkey',
#  'uefa clear execut committe member nasser al khelaifi punish despit find club pari http co h z jf',
#  'uefa clear execut committe member nasser khelaifi punish despit find club http co vhi mgkgfo',
#  'rt robeyremington awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http',
#  'rt alexkitmak concept kit athlet club tuescribestupropiahistoria design alexkitmak amp trick download http co mpwr',
#  'uefa exonera de castigo president del psg luego de ser se alado por presuntament amenazar lo rbitr http co vcwowfp ng',
#  'rt robeyremington awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http',
#  'yve bissouma es el tercer fichaj estelar del spur es tottenham tottenhamhotspur spur premierleagu http co udrjwexr',
#  'el mancity est pr cticament obligado ganar la ligadecampeon championsleagu con semejant ofensiva el p http co tehtjiy n',
#  'soccer sunday avail http co n jh eb worldcup worldcup qatar futbol soccer http co ulpc ol af',
#  'rt vicki ok final en el etihad semi ida championsleagu el manciti se impuso desd su idea de juego el realmadrid aprovech',
#  'suppli ball colleagu easili score soccer footbal futbol fifa futebol sport calcio http co coptmzeuab',
#  'rt pratamaa com era firmansah firmansah liverpool liverpoolfc mosalah firmino mane premierleagu championsleagu anfield ynwa',
#  'saturday bet readi discount new member join hurri join sportwetten skybet http co nfdzv fvop',
#  'era firmansah firmansah liverpool liverpoolfc mosalah firmino mane premierleagu championsleagu anfield http co dlp ptvgt',
#  'oi galera conhecem ditado que pagam os justo pelo pecador dom quijot vamosjuntospelobrasil http co lapwtvakgv',
#  'championsleagu todo listo para el arranqu de la nueva edici n de la champion leagu en vivo por tudn http co hozi sb kt',
#  'rt robeyremington awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http',
#  'uefa clear nasser al khelaifi misconduct champion leagu bust one match ban leonardo http co pccyo xsbd',
#  'el futbol de estufa est todo lo que da en europa mientra el brasil dani alv niega su llegada al http co paw fr',
#  'rt robeyremington awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'got realli smack smackdown championsleagu feelgoodfriday aew http co zrzkv v nu',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt robeyremington awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http',
#  'awesom finish smackdown championsleagu aew feelgoodfriday wweuniversalchampionship pmslive romanreign http co zxv uhbdu',
#  'pure awesom smackdown aew championsleagu feelgoodfriday wwesmackdown wweuniversalchampionship http co nqseobzeo',
#  'rt avatibor relax readi cl championsleagu http co zb mnlabq',
#  'footbal futbol messi r futsal championsleagu dalla usa cr futebol pulis puma nike neymar http co vtexftnrtu',
#  'de jugar contra el realmadrid en la championsleagu irs al f tbol de tailandia http co ed vke gy',
#  'man pepteam manciti sirk manciti manchest epl facup caraboacup championsleagu soccer http co airypj vm',
#  'fifa confirm back fifa world cup would play across north america full info http co ptmozzpzjf',
#  'forma sua dupla de ataqu championsleagu aguero teori ucl ucla http co xatci mon',
#  'beinsport bein bein ssc sport championsleagu http co vfg mlybdp',
#  'rt unit chariti countdown noch bi morgen auf die origin championsleagu schuhe von realmadrid star tonikroo bieten der erl g',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt salv amoroso napoli aslan baladz dg dinamobatumi adjarasporttv kvaratskhelia un giocator molto important per noi',
#  'clubnecaxa lo vi jugar en la ltima final de la championsleagu',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt infoaumax championsleagu rmdpsg officiel al khelaiffi et leonardo conna leur sentenc pour le sordr au match retour',
#  'championsleagu rmdpsg officiel al khelaiffi et leonardo conna leur sentenc pour le sordr au match http co rz hubv f',
#  'rt monascop qui sera le vainqueur de l appel offr championsleagu le contrat la batail annonc f roce entr',
#  'arsen never major european trophi championsleagu europaleagu bigclub coy thfc spur http co w pwttyeri',
#  'tntsportsbr ess jogo sempr ser inesquec vel jogo contra bayern de muniqu pela championsleagu e um show http co hdqkb amg',
#  'ess jogo sempr ser inesquec vel jogo contra bayern de muniqu pela championsleagu e um show de marcelo e http co fxk sqfxjm',
#  'rt cristiano everyth achiev goal red devil mufc championsleagu http',
#  'disrespect goal messi boateng bayern ucl championsleagu http co wo cxdolxb',
#  'rt julienodoul depui le attentat islamist du novembr nou savon que le stadedefr est une cibl pour le terrorist',
#  'http co xpmzqikuwb uefa psg leonardo alkhelaifi calcio realmadrid championsleagu',
#  'rt allanbart macron va finir par appr cier le fran ai darmanin stadedefr darmanin darmanindemiss macron lallement',
#  'rt allanbart il ne leur rest plu que le sort oubliett lancer sur le lecteur avant le l gisl accio la moula',
#  'algu passou torcer ou tomar dio real madrid naquela poca conta sextoucomsdesaudad realmadrid http co b tfiq e',
#  'http co yuf vk xla footbal soccer messi ronaldo championsleagu barcelona realmadrid neymar cr http co tq kdyp',
#  'rodrygo rivela con modric abbiamo preso giro salah dopo la final di championsleagu http co tpywbb kwm',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'clamarchisio juventusfc tudor contro il deportivo al esimo championsleagu tudor',
#  'rt khatchcard live tonight instagram khatch card f livebreak prizm whodoyoucollect nba nfl championsleagu futbol soccer',
#  'thank dtathlet jamespearcelfc lfc ynwa jft livrma realmadrid uclfin championsleagu http co mblgolhfi',
#  'best st fifa mobil icon ronaldo player review amp gameplay event icon r review link http co pz ttazdo',
#  'rt mattiasarvidss must read ladi gentlemen lfc ynwa jft livrma liverpool liverpoolfc liverpoolrealmadrid liver',
#  'must read ladi gentlemen lfc ynwa jft livrma liverpool liverpoolfc liverpoolrealmadrid http co xmfger r',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'live tonight instagram khatch card f livebreak prizm whodoyoucollect nba nfl championsleagu futbol http co hqthzcjg',
#  'watch camila cabello highli energ uefa perform http co zhqmj smzz camilacabello championsleagu http co wkqqr ls',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt prefet communiqu en raison de v nement survenu au stade de franc hier au soir le match de barrag entr l exelcior bondig',
#  'fill common knowledg franchis sport win franchis player http co iid gwcxa',
#  'got partner follow footbal use summer break tell big match yo http co nrlvzuhsau',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'absolut scene darwin nunez score hattrick anfield send lfc anoth championsleagu fin http co sxyubwgfqj',
#  'rt allanbart macron va finir par appr cier le fran ai darmanin stadedefr darmanin darmanindemiss macron lallement',
#  'rt act pal rememb celtic fine uefa fli palestin flag championsleagu play match hapo',
#  'rt iamcul thank reveng championsleagu',
#  'rt avatibor relax readi cl championsleagu http co zb mnlabq',
#  'realis rodrygo ucl goal madrid la liga goal realmadrid championsleagu http co vezjvuiiy',
#  'safeti sake champion leagu final chao still need full investig david conn ucl championsleagu http co r ojrt gxv',
#  'relax readi cl championsleagu http co zb mnlabq',
#  'rt realmadridcffr l uefa suspendu leonardo pour un seul match pour l incid au bernabeu nasser al khelaifi pa interdict',
#  'rt iamcul thank reveng championsleagu',
#  'diarioa tien raz n la tuvo un sabor muy especi realmadrid championsleaguefin championsleagu',
#  'thank reveng championsleagu http co uipfsh nn',
#  'che ne pensat dimaria argentina calciomercato championsleagu qatar qatar http co oxfiwugpl',
#  'yve bissouma welcom spursoffici final hit big time ignor nonsens feed http co adgo su',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt realmadridcffr l uefa suspendu leonardo pour un seul match pour l incid au bernabeu nasser al khelaifi pa interdict',
#  'l uefa suspendu leonardo pour un seul match pour l incid au bernabeu nasser al khelaifi pa interdicti http co ogfrwl',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'rt uefacom fr ucl ldc il pile un l attaqu sadio man inscrivait un anthologi avec liverpool contr le bayer',
#  'rt espn fdj gol del citi ant de lo do minuto de bruyn adelanta lo sky blue manciti realmadrid ucl championsl',
#  'rt chimaobibank let take destini hand peterobi presid peterobi peterobi presid newmoney requir',
#  'aspor biz di erleri biri jk daima bu lkede olarak kalacak bunlar n da motiv olma abalar bunlar http co mbi dmm',
#  'bobspur afc f blew point lead game play bottl championsleagu end th http co j ldn xmxj',
#  'rt salvigfx mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal footballart soc',
#  'rt realmadridcffr leonardo est condamn match de suspens par l uefa suit se agiss l encontr de arbitr apr real',
#  'leonardo est condamn match de suspens par l uefa suit se agiss l encontr de arbitr apr r http co mklxdimzc',
#  'championsleagu apostasesportiva apostaganha futebol marketingdigit marketingdeconteudo acr tocantin http co ijocczjluv',
#  'rt lucholass estreno nueva camiseta away del celticfc x adidasfootbal para al temporada de la spfl champio',
#  'che ne pensat skriniar inter seriea championsleagu ucl calciomercato http co nrvg srj k',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'estreno nueva camiseta away del celticfc x adidasfootbal para al temporada de la spfl http co hs h xw',
#  'championsleagu handballcoup f r die lanxessarena http co zpisyv g via reportkoeln',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'kick ball went play championsleagu final transfer adida alon http co ixdzh v z',
#  'european golden shoe stand http co etd euja robert lewandowski goal kylian mb http co csx okn',
#  'rt policiasxxi hilo con la intervencion de josemavallejo en horizont el para tratar la inseguridad el cao vivido en',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt celticview championsleagu return paradis day june look tho',
#  'rt azizzemouri stade de franc le nateur chargent le pr fet prefpolic didier lallement sur de faux l ment le point stadefr',
#  'rodrygo revela provoca de modric salah na pr xima tenta de novo rodrygo modric salah realmadrid http co ahfsenqkeg',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'rodrygo champion leagu final give guard honour liverpool salah come http co qy jwu z',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'championnat de plongeon sur la sein pari impressionn ce plongeoir tre au dessu de l eau http co spmpsfl',
#  'rt azizzemouri stade de franc le nateur chargent le pr fet prefpolic didier lallement sur de faux l ment le point stadefr',
#  'championnat de plongeon sur la sein pari impressionn ce plongeoir tre au dessu de l eau http co kyu nbjqae',
#  'stade de franc le nateur chargent le pr fet prefpolic didier lallement sur de faux l ment le point http co wcxdv quy',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'rt sportybet rodrygo champion leagu final give guard honour liverpool salah come bit sad',
#  'rodrygo champion leagu final give guard honour liverpool salah come http co uxl lvhjiy',
#  'fcbarcelona never look statement messi realmadrid barcelona psg juventu http co j lfffe w',
#  'se estableci el calendario de la ligu el naco debutar el de agosto en estrasburgo lo dem riv http co yghuuyefh',
#  'rt ukairband seen top googlesearch may lot drama not talk johnnydepp amp',
#  'rt salvigfx mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal footballart soc',
#  'rt salvigfx mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal footballart soc',
#  'rt salvigfx mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal footballart soc',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt grimaldisabrina stadedefr championsleagu darmanin http co drej q oc',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'still day end transfer window dear nufc fan worri strong window current http co drj ynamok',
#  'rt salvigfx mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal footballart soc',
#  'mi dise para el rmeditchalleng de realmadrid adob footballdesign smsport soccer footbal http co qsw xw ixu',
#  'rt unit chariti toll f r die championsleagu schuhe von tonikroo wir freuen un mit gewinn au den usa und der tkstift',
#  'rt allanbart jamai de leur faut darmanin lallemand ucl uefa championsleaguefin championsleagu stadedefr pour financ',
#  'luka modric se lo tom person con salah rodrygo goe ha revelado en un podcast la frase que dijo modric sal http co xagavbpepj',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'predict player win fifaworldcup worldcup qatar ucl championsleagu http co agtvebviei',
#  'rt hugo cnm viendo el calendario de la championsleagu del que vien la semi serian de mayo eso dir que descarta',
#  'rt sport xpert eight year ago lui suarez join barcelona born trio differ level',
#  'summer rafaelnad win rolandgarro warrior win nba championship realmadrid win http co x mccun tt',
#  'man lleg al liverpoolfc en el desd aquel el camp n de la copa de frica ha disputado par http co hyrpfckf b',
#  'gooner forev egtveg bro six season row still championsleagu take v http co cwwh b',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt eldiarhincha ok primer contrato profesion isma l gharbi promesa francesa de os firm su primer contrato profesion co',
#  'le migliori foto di monicabertini del mese di maggio monicabertini itali sport calcio mediaset http co v ctlvtd',
#  'primer contrato profesion isma l gharbi promesa francesa de os firm su primer contrato profesion http co yphialypec',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'gooner forev egtveg bro point front game go gass done http co zhhyrfuwi',
#  'repasemo lo n mero de sadio mane ha lo largo de esto os partido gole asistencia http co bsyxvaamga',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'moitier du chemin h est presqu valhalla entraid acmilan america btc btc championsleagu crypto eth http co uvuziwucat',
#  'winston bettsstev egtveg steve bett thfc sign player assana fan prefer http co porprvdemn',
#  'foxnew absolut detest fifacom sooner fifa disband new world footbal organis set http co uf ybtscxx',
#  'egtveg mate thfc timelin afc lee gunner right total melt http co xnhmz cebt',
#  'rt paulinamkama congrat stephencurri final mvp nba champion welcom celebr championship tan',
#  'luka modric let mo salah know http co x zwm wbsx uefa championsleagu espncaribbean http co spl fbpkkn',
#  'championsleagu semana despu de haber ganado el tulo del important torneo se conocen alguno detal de http co vaqdcxgctm',
#  'rt themattdp juventu pronto un clamoroso scambio seri http co rkd qz vn ronaldo juventu paratici marotta forzaj',
#  'championsleagu return paradis day june look http co fatesecva',
#  'rt unit chariti toll f r die championsleagu schuhe von tonikroo wir freuen un mit gewinn au den usa und der tkstift',
#  'juventu pronto un clamoroso scambio seri http co rkd qz vn ronaldo juventu paratici marotta http co zszh nxitx',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt humourbiglol la tv espagnol montr la v rit du stade de franc en direct et truit la version lament de darmanin darmanin',
#  'ya lo dijo zp os acord estamo en championsleagu de la econom sanchezcastejon tambi n la inflacion http co eopfsruifc',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt syscom laurent lafon l tat fran ai doit expliqu sur qui est respons de quoi et quell erreur ont fait staded',
#  'rt humourbiglol la tv espagnol montr la v rit du stade de franc en direct et truit la version lament de darmanin darmanin',
#  'lidz narod w losowaniu w el championsleagu lechpoznan wyborz trenera kolejorza w rozmowi z http co bpj uatofp',
#  'rt smkstd athen memor night everi milan fan thank pippo filippo inzaghi insist greatest goal ever score',
#  'justo con la parada de ese penalti empez la va aporla halamadrid hastaelfinalvamosr http co njiiv ujj',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'choolosimeon elchiringuitotv hay tipo de tonto tonto con championsleagu tonto sin http co gj kxsrgke',
#  'podr formar el asm naco si hubieran vendido nadi equipo para pelear la championsleagu http co uiezaci',
#  'hast du den live ausrast von toni kroo beim championsleagu final mitverfolgt damit du der n chsten cl http co gbdlqvhqxk',
#  'cont effect best thing happen spursoffici club thank cont make us beli http co spfg lm',
#  'la nuova edizion della championsleagu gi iniziata con la sua fase preliminar attesa di aver il quadro c http co eretyfvppz',
#  'championsleagu un ma que ma http co wtlb iqxpl',
#  'odd lfc draw fcbayernen championsleagu skybet bet',
#  'rt bhdazueira abertura da final da championsleagu tava parecendo arraial de bh http co qaqbodmepd',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt realmadridcffr rodrygo quand quelqu un te provoqu parfoi tu veux gagner just pour voir sa te l entra nement disait',
#  'know liverpool face bayern munich sadio mane point championsleagu next season',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt realmadridcffr rodrygo quand quelqu un te provoqu parfoi tu veux gagner just pour voir sa te l entra nement disait',
#  'rt crackdeportivo lautaro mart nez la premier leagu lautaro mart nez actualment en el inter de italia recibi oferta del',
#  'elm termini pierwszych mecz w lecha pozna ucl championsleagu http co ejf c r g',
#  'rt esportudobr que isso modric os cara n estavam pra brincadeira na final da champion ganharam e tiraram onda futebol ligad',
#  'rodrygo quand quelqu un te provoqu parfoi tu veux gagner just pour voir sa te l entra nement disai http co cx vwbaxyv',
#  'rt unit chariti toll f r die championsleagu schuhe von tonikroo wir freuen un mit gewinn au den usa und der tkstift',
#  'europacnfleagu ardagul fenerbahc en showtim championsleagu',
#  'lautaro mart nez la premier leagu lautaro mart nez actualment en el inter de italia recibi oferta de http co prknflnwt',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt ragnarok day day bo v win w v lose v tie lw v lose wl min',
#  'lost champion leagu name remov media balloon award racism http co dhmvlkve n',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt esportudobr que isso modric os cara n estavam pra brincadeira na final da champion ganharam e tiraram onda futebol ligad',
#  'rt medalion place manchest unit win champion leagu trophi rn manunit championsleagu http co',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'cuoreischitano aggiungo tifosidelquartoposto felici che putecaro raggiung la championsleagu e sistema tutta la famiglia',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt videosmodern liverpool offens phase vs realmadrid championsleagu numer superior fals nine wide r',
#  'rt medalion place manchest unit win champion leagu trophi rn manunit championsleagu http co',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'rt esportudobr que isso modric os cara n estavam pra brincadeira na final da champion ganharam e tiraram onda futebol ligad',
#  'rt madridcamiseta chico chica ayudemo anna rm para llegar lo k ella siempr ayuda toda la cuenta pequ no toca',
#  'l monaco va passer un joli moi ao entr la ligu et le qualif de championsleagu http co n xitdtz z',
# ...
#  'post post champion leagu championsleagu championsleaguefin footbal',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'break news albert botin agent di deulofeu ha dichiarato con spalletti sarebb perfetto all spall di http co gzghicdqpi',
#  'rt belagool si mejor hablamo del gigant de europa realmadrid madrid championsleagu http co qcpzixdlip',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'rt videosmodern realmadrid possess vs liverpool championsleagu base shape vacat danger area crea',
#  'realmadrid possess vs liverpool championsleagu base shape vacat danger area http co rkd hgncaq',
#  'pool set let gooo championsleagu ecnlgirl thesoccerwir imcollegesocc prepsocc http co rw usbemn',
#  'campeonatobrasileiro brasil pernambuco alagoa paraiba riograndedonort ceara campeonatocarioca http co nc xndptow',
#  'apostasesportiva apostaganha futebol marketingdigit marketingdeconteudo acr tocantin amazona http co ecqmak jt',
#  'qww fcb espnfc obvious psg bigger madrid psg face madrid championsleagu',
#  'rt ncn kiss kiss agent deulofeu verrebb napoli di corsa vuol giocar la champion deulofeu agent napoli corsa champi',
#  'kiss kiss agent deulofeu verrebb napoli di corsa vuol giocar la champion deulofeu agent napoli http co cvsupikr',
#  'kiss kiss agent deulofeu verrebb napoli di corsa vuol giocar la champion deulofeu agent napoli http co pkz fgzrwj',
#  'ibra offici vs sergioramo trollfootbal championsleagu http co lgaddfr',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'tu imss boicotburgerk championsleagu la cl nica lo ba os sucio sin jab n dicen vaya medicina prev http co j j kicseh',
#  'rt pavon bring manciti champion leagu manciti erlinghaaland edit pavon manciti brfootbal championsleag',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'http co yuf vjnwtc footbal soccer messi ronaldo championsleagu barcelona realmadrid neymar cr http co lpk qu u',
#  'championsleagu liverpool champion leagu final chao leav french offici mani regret michel cadot http co zczgmwpi',
#  'rt terenc jnr marvininu marvin mar invas inevit btc bnb bsc bscgem championsleagu eth http co osvbmzijj',
#  'premierleagu manciti astonvilla may nd game one age boost could given http co aayzztr w',
#  'rt thecrankypundit everyth cranki pundit got wrong season good podcast associ msccasino',
#  'provid ball team mate easili score soccer footbal futbol fifa futebol sport calcio http co p fcfhkh',
#  'rt uefacom fr ucl quand tu es l tu es intouch joyeux anniversair j rgen klopp ldc championsleagu http co spp',
#  'everyth cranki pundit got wrong season good podcast associ http co qryrrpi f',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'june th alfi haaland june th erl haaland manciti sign father son duo http co ongpuv',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'championsleagu apostasesportiva apostaganha futebol marketingdigit marketingdeconteudo acr tocantin http co rc ympt ee',
#  'juventusfc mattia desci quando championsleagu affronti terzini liverpool real madrid manchest citi ec http co snx otvyd',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt themattdp allegri furioso con la juventu offerta del psg http co oxuxsvmo c ronaldo juventu paratici marotta forzaj',
#  'allegri furioso con la juventu offerta del psg http co oxuxsvmo c ronaldo juventu paratici marotta http co vykxibijsk',
#  'new championsleagu format fuck horribl european super leagu would better',
#  'p rez europ isch super leagu noch nicht vom tisch championsleagu ucl realmadrid realmadridfan rmliga http co sb nombu',
#  'rt smartfix believ still life today rememb struggl pay landlord',
#  'rt sportitalia il barcellona attivissimo sul mercato e progetta un colpo fastidioso per la juve le ultim juventu seriea',
#  'livraison whatsapp appel sm wckr gameur snaptchat empir market l gramm http co bmaakt bnj',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'dybala sempr pi nerazzurro dopo la cena anch le vacanz con correa prove di inter miami lo http co bdp nulvhd',
#  'rt lellokata goalitalia esto e la uefa ceferinout ceferindimis uclfin uefachampionsleaguefin ucl championsleagu',
#  'rt allanbart jamai de leur faut darmanin lallemand ucl uefa championsleaguefin championsleagu stadedefr pour financ',
#  'rt allanbart macron va finir par appr cier le fran ai darmanin stadedefr darmanin darmanindemiss macron lallement',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'galliani urla co fort che gli occhi gli schizzano dall orbit la testa gli si gonfia diventa blu e esplod sveg http co c futpf',
#  'rt maryummari paul kabali manchesterunit die hard may live lift championsleagu trophi pleas buseinsamilu',
#  'favourit memori bhoy champion leagu celtic championsleagu tbt http co ho vkxgn',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'rt salv amoroso napoli aslan baladz dg dinamobatumi adjarasporttv kvaratskhelia un giocator molto important per noi',
#  'paul kabali manchesterunit die hard may live lift championsleagu trophi pleas http co pyxjwafpuh',
#  'gentlemen footbal brand soccer footbal style worldcup menwithclass classygentlemen eleg http co rdrfgsfrf',
#  'rt champion land nft nft collector nftbuyer nftsale giveaway nftgiveaway nftgiveaway nftmarket nftmagazin nftsport spor',
#  'rt unrulymass head soccer soccer footbal futbol fifa futebol sport calcio sport premierleagu messi championsleagu',
#  'head soccer soccer footbal futbol fifa futebol sport calcio sport premierleagu messi http co yijrrayghl',
#  'rt mediavenir flash le imag de vid osurveil du stadedefr sur lesquel pouvait voir de sc ne extr mement violent',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'rt jzr product bissouma spur tiktok would appreci retweet feedback spur transfer bissouma championsleagu',
#  'readi atleticomadrid footballzon http co e dkbbaivn',
#  'rt sercant europaleagu buri asen uefa cup real madrid super cup galatasaray becam',
#  'la mejor championsleagu de la historia http co il eojoo',
#  'rt champion land nft nft collector nftbuyer nftsale giveaway nftgiveaway nftgiveaway nftmarket nftmagazin nftsport spor',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'europaleagu buri asen uefa cup real madrid super cup galatasaray becam http co zwiehpig',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'rt unit chariti countdown noch bi morgen auf die origin championsleagu schuhe von realmadrid star tonikroo bieten der erl g',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt allanbart il ne leur rest plu que le sort oubliett lancer sur le lecteur avant le l gisl accio la moula',
#  'mercredi juin la fifa communiqu le calendri complet de la prochain coup du mond qui aura lieu au qatar http co r gtymhazb',
#  'rt videogameyeezu new video championsleagu topp topp uefa champion leagu chrome soccer lite box open http',
#  'fichajazo absoluto para cont bissouma como acompa ant de bentancur h jbjerg en la medular para competir por l http co benymshwdr',
#  'rt allanbart il ne leur rest plu que le sort oubliett lancer sur le lecteur avant le l gisl accio la moula',
#  'new video championsleagu topp topp uefa champion leagu chrome soccer lite box open http co tl qaqmzl',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt liliana championsleagu realmadrid http co ibvkmbflsd',
#  'yve bissouma excit prospect play championsleagu work antonio cont http co dhtuymzt',
#  'rt metasocc en metasocc announc realmadrid player tomorrow exclus licens championsleagu winner g',
#  'paul pogba take anoth swipe manchest unit new amazon prime documentari ucl championsleagu metro http co sip q wzb',
#  'rt interiorgob sabe c mo se proteg un partido de alto riesgo entramo en el dispositivo de policia para el realmadrid mancity',
#  'bissouma spur tiktok would appreci retweet feedback spur transfer bissouma championsleagu http co gvhhd chqk',
#  'battl titan worldcup footbal soccer fifa cricket futbol ipl viratkohli championsleagu messi http co ko pdho j',
#  'rt champion land nft nft collector nftbuyer nftsale giveaway nftgiveaway nftgiveaway nftmarket nftmagazin nftsport spor',
#  'serieatim efootbal acmilan championsleagu http co sjug qi sg',
#  'rt champion land nft nft collector nftbuyer nftsale giveaway nftgiveaway nftgiveaway nftmarket nftmagazin nftsport spor',
#  'nft nft collector nftbuyer nftsale giveaway nftgiveaway nftgiveaway nftmarket nftmagazin nftsport http co xiamgxbfxp',
#  'rt themattdp non solo pogba di maria alla juventu arriva la decision http co qx fnomat ronaldo juventu paratici maro',
#  'rt patrick hd querido equipo que la voce de la afici n os gu en hacia la victoria vamo todo junto porqu somo uno somo el',
#  'florentino perez est mbapp es mi mbapp crazi footbal fan http co b bmwjea v trav de youtub http co hnvahioebp',
#  'florentino perez est mbapp es mi mbapp crazi footbal fan http co b bmwjea v trav de youtub http co v bjib z',
#  'non solo pogba di maria alla juventu arriva la decision http co qx fnomat ronaldo juventu http co lchqjacdd',
#  'florentino perez est mbapp es mi mbapp crazi footbal fan http co b bmwjea v trav de youtub http co ki sazew',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'actual break champion leagu panini sticker pack open http co vt xbadcrx salah http co bbk qntc',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt uelestartit presentaci del project nior l estartit ha tornat fcf cat futbol footbal soccer barcelona uelestartit fcb',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt undefet throwback septemb gilberto score second psv eindhoven championsleagu group philip',
#  'rt supporterslif ultra curva sud milano minut pure must see video youtub http co ozkwqaa vb curvasud curva',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt woodwoodpyt babi score mazi run commentari miltio goal inter milan bayern munich ucl final everi goal',
#  'rt uefacom fr ucl quand tu es l tu es intouch joyeux anniversair j rgen klopp ldc championsleagu http co spp',
#  'throwback time messi suarez use match polit sent gari nevil sky sport messi http co oaihexfo',
#  'marcelo realmadrid soccer championsleagu http co trrkfejgzt',
#  'rt sonicasit team strongest attack opinion manchest citi liverpool pari g sorar manciti li',
#  'rt happymannft pig area price polygon blockchain ga fee link bio btc bitcoin crypto cryptocurren',
#  'team strongest attack opinion manchest citi liverpool pari g sorar http co yqjbod',
#  'rt uefacom fr ucl quand tu es l tu es intouch joyeux anniversair j rgen klopp ldc championsleagu http co spp',
#  'rt unit chariti countdown noch bi morgen auf die origin championsleagu schuhe von realmadrid star tonikroo bieten der erl g',
#  'ucl quand tu es l tu es intouch joyeux anniversair j rgen klopp ldc championsleagu http co spp rniaq',
#  'rt undefet throwback septemb gilberto score second psv eindhoven championsleagu group philip',
#  'rt uelestartit presentaci del project nior l estartit ha tornat fcf cat futbol footbal soccer barcelona uelestartit fcb',
#  'presentaci del project nior l estartit ha tornat fcf cat futbol footbal soccer barcelona http co cp k pvk',
#  'uefa allow arsen benwhit wear championsleagu patch shirt next season thfc spur http co z lnum xn',
#  'rt supporterslif ultra curva sud milano minut pure must see video youtub http co ozkwqaa vb curvasud curva',
#  'ultra curva sud milano minut pure must see video youtub http co ozkwqaa vb curvasud http co w nsfxsweu',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt terenc jnr marvininu marvin mar invas inevit btc bnb bsc bscgem championsleagu eth http co osvbmzijj',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'florentino perez mbapp aujourd hui un r bien plu grand que tre seulement un joueur du real mbapp est http co mawtssfwp',
#  'rt policia quier ver c mo montamo un dispositivo de seguridad para un partido de alto riesgo pont en la piel de nuestro agent',
#  'rt mediavenir flash le imag de vid osurveil du stadedefr sur lesquel pouvait voir de sc ne extr mement violent',
#  'rt realmadridcffr florentino p rez j ai entendu de commentair absurd sur notr ligu de champion c est encadr si nou',
#  'rt terenc jnr marvininu marvin mar invas inevit btc bnb bsc bscgem championsleagu eth http co osvbmzijj',
#  'rt mediavenir flash la justic demand le imag de vid osurveil du stadedefr hier jour apr le fait malgr le',
#  'rt realmadridcffr florentino tout le mond est lev au bernab u quand rodrygo marqu sauf moi par respect pour la personn',
#  'believ still life today rememb struggl pay landl http co bu ga nn',
#  'rt realmadridcffr florentino p rez nou comprenon qu il veulent nou expropri no droit tv pendant an et nou n avon au',
#  'rt realmadridcffr florentino perez l uefa est un monopol leur menac nou n avon jamai eu peur eux realmadrid rmaliv',
#  'rt realmadridcffr florentino perez peur que ceferin nou expuls de la cl non jamai elchiringuitotv realmadrid rmaliv',
#  'championsleagu celticfc']

# %%
''' count vectorizer '''
count_vector = CountVectorizer(max_features=2500) 

''' independent and dependent variables '''
X = count_vector.fit_transform(c).toarray()
y = data.iloc[:, 1].values

''' checking shape '''
print(X.shape)
print(y.shape)
# Out:
# (1000, 2500)
# (1000,)

# %% [markdown]
# ## Random Forest Classifier

# %%
''' train test split '''
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
''' Min Max Scaler '''
min_max_sc = MinMaxScaler()

X_train = min_max_sc.fit_transform(X_train)
X_test = min_max_sc.transform(X_test)

# %%
rf = RandomForestClassifier()

''' fit on data '''
rf.fit(X_train, y_train)

''' prediction '''
y_pred = rf.predict(X_test)

''' confusion matrix '''
plt.figure(figsize=(10, 10))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g');
plt.title('Confusion Matrix', fontsize=20);

# %% [markdown]
# ## Hyperparameter Tunning

# %%
p = {
    'bootstrap': [True],
    'max_depth': [80, 100],
    'min_samples_split': [8, 12],
    'n_estimators': [100, 300]
}

''' Grid Search CV '''
grid_cv = GridSearchCV(estimator=rf, param_grid=p, cv=10, verbose=0, scoring='accuracy', n_jobs=-1, 
                       return_train_score=True)
grid_cv.fit(X_train, y_train.ravel())
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [80, 100],
#                          'min_samples_split': [8, 12],
#                          'n_estimators': [100, 300]},
#              return_train_score=True, scoring='accuracy')

# %%
print("Best Parameter : {}".format(grid_cv.best_params_))
# Out:
# Best Parameter : {'bootstrap': True, 'max_depth': 100, 'min_samples_split': 12, 'n_estimators': 100}

# %%
rf_cv = RandomForestClassifier(bootstrap=True, max_depth=80, min_samples_split=8, n_estimators=300)

''' fit on data '''
rf_cv.fit(X_train, y_train)

''' prediction '''
pred = rf_cv.predict(X_test)

# %%
''' confusion matrix '''
plt.figure(figsize=(10, 10))
sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='g');
plt.title('Confusion Matrix', fontsize=20);
